# %%
# !pip install datasets
# Out:
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.50.2
#     Uninstalling tqdm-4.50.2:
#       Successfully uninstalled tqdm-4.50.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.8.3
#     Uninstalling fsspec-0.8.3:
#       Successfully uninstalled fsspec-0.8.3
# ...
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# huggingface-hub 0.9.1 requires packaging>=20.9, but you'll have packaging 20.4 which is incompatible.

# %%
import datasets

# %%
import pandas as pd

# %%
from datasets import load_dataset

dataset = load_dataset("aeslc")
# Out:
# Using custom data configuration default
# Found cached dataset aeslc (C:/Users/mchou/.cache/huggingface/datasets/aeslc/default/1.0.0/eb8e30234cf984a58ebe9f205674597ac1db2ec91e7321cd7f36864f7e3671b8)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['email_body', 'subject_line'],
#         num_rows: 14436
#     })
#     validation: Dataset({
#         features: ['email_body', 'subject_line'],
#         num_rows: 1960
#     })
#     test: Dataset({
#         features: ['email_body', 'subject_line'],
#         num_rows: 1906
#     })
# })

# %%
source_train_df = pd.DataFrame(dataset["train"])

# %%
source_train_df
# Out:
#                                               email_body  \
# 0      Greg/Phillip,  Attached is the Grande Communic...
# 1      Phillip & Keith  Attached is the first draw re...
# 2      Your Internet Banking accounts are now setup a...
# 3      To our IBS Customers that are still hanging in...
# 4      Phillip Good Morning!\nI hope you had a wonder...
# ...                                                  ...
# 14431  This email is acknowledgement from the Power P...
# 14432  This email is acknowledgement from the Power P...
# 14433  John,  Further to the voice message that I lef...
# 14434  Make sure that all curves are downloaded by th...
# 14435  John:  Do you need Accumap day one?\nCarmen sa...
#
#                   subject_line
# 0            Service Agreement
# 1               Bishops Corner
# 2             Internet Banking
# 3             Internet Banking
# 4      SMEs for expert stories
# ...                        ...
# 14431               Power Pool
# ...

# %%
for i in source_train_df['email_body']:
    
    print(i)
# Out:
# Greg/Phillip,  Attached is the Grande Communications Service Agreement.
# The business points can be found in Exhibit C.  I Can get the Non-Disturbance agreement after it has been executed by you and Grande.
# I will fill in the Legal description of the property one I have received it.
# Please execute and send to:  Grande Communications, 401 Carlson Circle, San Marcos Texas, 78666 Attention Hunter Williams.
# <<Bishopscontract.doc>>
#
# Phillip & Keith  Attached is the first draw request, I will need some of these funds immediately.
# I think checks out of Bishops Corner, L.P. may be the easiest, or you can wire money to me and I can write the checks when needed.
# Please let me know how you wish to handle this and I will proceed.
# Additionally, it is getting close to closing.
# I will need to get contracts signed at this point as soon as possible.
# We can handle this in two ways.
# ...

# %%
f = open("test.txt", "w")
f.write("Woops! I have deleted the content!")
f.close()

# %%
for i in range(5):
    filename = "filename"+str(i)+".txt"
    print(filename)
    f = open(filename, "w")
    f.write("Woops! I have deleted the content!")
    f.close()
# Out:
# filename0.txt
# filename1.txt
# filename2.txt
# filename3.txt
# filename4.txt

# %%
counter = 1
for i in source_train_df['email_body']:
    filename = "source_data"+str(counter)+".txt"
    f = open(filename, "w")
    f.write(i)
    f.close()
    counter = counter +1
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
source_validation_df = pd.DataFrame(dataset["validation"])

# %%
source_validation_df
# Out:
#                                              email_body  \
# 0     Hi Phillip,  This message is to confirm our me...
# 1     Phillip;  Could you please e-mail me the draw ...
# 2     Jeff/Brenda:  Please authorize the following p...
# 3     Patti,  This sounds like an opportunity to lan...
# 4     Don't make me pull tapes on whether you unders...
# ...                                                 ...
# 1955  As of start of business, Wednesday, February 6...
# 1956  Further to our meeting today, please find atta...
# 1957  With the filing of the Hart-Scott-Rodino appli...
# 1958  Tricia, John has a stock option amount reporte...
# 1959  John, we just received an invoice from the abo...
#
#                                            subject_line
# 0     Confirmation: Risk Management Simulation Meeti...
# 1                                      Bishops Corner\n
# 2                                                 eol\n
# 3                 Analyst Interviews Needed - 2/15/01\n
# ...

# %%
counter = 1
for i in source_validation_df['email_body']:
    filename = "validation_data"+str(counter)+".txt"
    f = open(filename, "w")
    f.write(i)
    f.close()
    counter = counter +1
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
source_test_df = pd.DataFrame(dataset["test"])

# %%
source_test_df
# Out:
#                                              email_body  \
# 0     Phillip,   Could you please do me a favor?\nI ...
# 1     The following reports have been waiting for yo...
# 2     We have for the last couple of weeks started t...
# 3     Michelle Here are my very minor comments.\nHow...
# 4     For purposes of an accelerated distribution fr...
# ...                                                 ...
# 1901  Andy,  Stephanie Sever has contacted ICE and h...
# 1902  The following was developed in an effort to as...
# 1903  REMINDER:  Your weekly update for Philippe and...
# 1904  Please find attached the latest, and what shou...
# 1905  John,  Further to our conversation last week, ...
#
#                                            subject_line
# 0                                    Huntley/question\n
# 1              Expense Reports Awaiting Your Approval\n
# 2                       Re-start/Integration Planning\n
# 3     RM Simulation Storyline Scripts - Ready for Le...
# ...

# %%
counter = 1
for i in source_test_df['email_body']:
    filename = "test_data"+str(counter)+".txt"
    f = open(filename, "w")
    f.write(i)
    f.close()
    counter = counter +1
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
source_test_df['email_body'][1819]
# Out:
# 'I want to remind each of you to attend the Enron Employee Meeting tomorrow at 10 a.m. in the Hyatt Regency Imperial Ballroom.\nI hope to introduce many of you at the meeting, so please plan to sit up front.\nSeats will be held for you.\nThis will be a very important meeting.\nI look forward to seeing you there.\nRegards,\n'
